# %%
!,pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\berkk\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\berkk\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\berkk\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\berkk\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.4)
# Requirement already satisfied: colorama in c:\users\berkk\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    - ------------------------------------- 30.7/624.3 kB 660.6 kB/s eta 0:00:01
#    - ------------------------------------- 30.7/624.3 kB 660.6 kB/s eta 0:00:01
#    ----- --------------------------------- 92.2/624.3 kB 581.0 kB/s eta 0:00:01
#    ----- --------------------------------- 92.2/624.3 kB 581.0 kB/s eta 0:00:01
#    ------ ------------------------------- 112.6/624.3 kB 437.6 kB/s eta 0:00:02
#    ------------ ------------------------- 204.8/624.3 kB 692.4 kB/s eta 0:00:01
#    ------------ ------------------------- 204.8/624.3 kB 692.4 kB/s eta 0:00:01
#    ------------ ------------------------- 204.8/624.3 kB 692.4 kB/s eta 0:00:01
#    ------------ ------------------------- 204.8/624.3 kB 692.4 kB/s eta 0:00:01
#    ------------------- ------------------ 327.7/624.3 kB 724.7 kB/s eta 0:00:01
#    ------------------- ------------------ 327.7/624.3 kB 724.7 kB/s eta 0:00:01
#    ----------------------- -------------- 389.1/624.3 kB 673.0 kB/s eta 0:00:01
#    --------------------------- ---------- 450.6/624.3 kB 723.0 kB/s eta 0:00:01
#    -------------------------------- ----- 532.5/624.3 kB 796.1 kB/s eta 0:00:01
#    ----------------------------------- -- 583.7/624.3 kB 853.3 kB/s eta 0:00:01
#    -------------------------------------- 624.3/624.3 kB 854.0 kB/s eta 0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.5 MB 1.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.5 MB 1.8 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.5 MB 2.0 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.5 MB 1.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.5 MB 1.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.5 MB 1.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.5 MB 1.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.5 MB 1.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.5 MB 1.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.5 MB 1.4 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.5 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 1.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.5 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.5 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.5 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.5 MB 1.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.5 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.5 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.4/1.5 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: nltk, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# Successfully installed nltk-3.9.2 textblob-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %% [markdown]
# TEXTBLOB

# %%
sentence_1 = "i had a great time at the movie it was really funny"
sentence_2 = "i had a great time at the movie but the parking was terrible"
sentence_3 = "i had a great time at the movie but the parking wasn't great"
sentence_4 = "i went to see a movie"

# %%
print(sentence_1)
sentiment_score=TextBlob(sentence_1)
print(sentiment_score.sentiment.polarity)
# Out:
# i had a great time at the movie it was really funny
# 0.525

# %% [raw]
# TextBlob returns a score between -1 and 1, where negative scores indicate negative sentiment, and positive scores indicate positive sentiment.

# %%
print(sentence_2)
sentiment_score=TextBlob(sentence_2)
print(sentiment_score.sentiment.polarity)
# Out:
# i had a great time at the movie but the parking was terrible
# -0.09999999999999998

# %%
print(sentence_3)
sentiment_score=TextBlob(sentence_3)
print(sentiment_score.sentiment.polarity)
# Out:
# i had a great time at the movie but the parking wasn't great
# 0.8

# %%
print(sentence_4)
sentiment_score=TextBlob(sentence_4)
print(sentiment_score.sentiment.polarity)
# Out:
# i went to see a movie
# 0.0

# %% [markdown]
# VADER

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in c:\users\berkk\anaconda3\lib\site-packages (from vaderSentiment) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\berkk\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\berkk\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\berkk\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\berkk\anaconda3\lib\site-packages (from requests->vaderSentiment) (2025.11.12)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/126.0 kB ? eta -:--:--
#    --------- ------------------------------ 30.7/126.0 kB 1.4 MB/s eta 0:00:01
#    ------------ -------------------------- 41.0/126.0 kB 393.8 kB/s eta 0:00:01
#    ---------------------------- ---------- 92.2/126.0 kB 655.4 kB/s eta 0:00:01
#    ------------------------------ ------- 102.4/126.0 kB 538.9 kB/s eta 0:00:01
#    -------------------------------------- 126.0/126.0 kB 618.8 kB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader_sentiment = SentimentIntensityAnalyzer()

# %%
print(sentence_1)
print(vader_sentiment.polarity_scores(sentence_1))
# Out:
# i had a great time at the movie it was really funny
# {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.807}

# %%
print(sentence_2)
print(vader_sentiment.polarity_scores(sentence_2))
# Out:
# i had a great time at the movie but the parking was terrible
# {'neg': 0.234, 'neu': 0.621, 'pos': 0.144, 'compound': -0.3818}

# %%
print(sentence_3)
print(vader_sentiment.polarity_scores(sentence_3))
# Out:
# i had a great time at the movie but the parking wasn't great
# {'neg': 0.247, 'neu': 0.611, 'pos': 0.142, 'compound': -0.4387}

# %%
print(sentence_4)
print(vader_sentiment.polarity_scores(sentence_4))
# Out:
# i went to see a movie
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %% [markdown]
# Logic Summary of the Code
# TextBlob: Uses a simpler, word-based dictionary. It's fast, but may miss complex language structures (like negations).
#
# VADER: The rules are more developed. He understands professionally that conjunctions such as "but" (but) change the direction of the sentence and suffixes "not" (not).
